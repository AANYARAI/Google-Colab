# %% [markdown]
# <a href="https://colab.research.google.com/github/AANYARAI/Google-Colab/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x=[10,20,30,40,50]
y=[20,15,25,30,35]
plt.title('Bar Graph')
plt.bar(x,y,color='plum' , width=3)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
x=[10,20,30,40,50]
y=['AANYA','RIDEEMA','ANANTA','PRIYAL','ASHI']
plt.title('Pie Chart')
plt.pie(x,labels=y)
plt.show()

# %%
import pandas as pd

# %%
data=pd.read_excel("Book2.csv.xlsx")
print(data)
# Out:
#    s no. Name Branch  Sem
# 0      1    A    CSE  3RD
# 1      2    B   AIML  5TH
# 2      3    C     DS  2ND
# 3      4    D   CSBS  1ST

# %%
import seaborn as sns

# %%
data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
import seaborn

# %%
data=seaborn.load_dataset("iris")
seaborn.scatterplot(data=data)
# Out:
# <Axes: >
